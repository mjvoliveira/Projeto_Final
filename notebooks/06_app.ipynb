# %%
import pandas as pd

# %%
df = pd.read_parquet("../data/processed/forecast_monthly_all_centers.parquet")

print(df.columns)
# Out:
# Index(['MONTH', 'y_hat', 'CFGCENTROID'], dtype='str')

# %%
df2 = pd.read_parquet("../data/intermediate/data_clean.parquet")

print(df2.columns)
# Out:
# Index(['CENTRO_ID', 'DATA_RECEPCAO'], dtype='str')

# %%
df2 = pd.read_parquet("../data/processed/backtest_metrics_all_centers.parquet")

print(df2.columns)
# Out:
# Index(['CFGCENTROID', 'real', 'previsto', 'mae', 'rmse', 'wape'], dtype='str')

# %%
df2 = pd.read_parquet("../data/processed/backtest_plot_all_centers.parquet")

print(df2.columns)
# Out:
# Index(['CFGCENTROID', 'date', 'real', 'previsto'], dtype='str')
